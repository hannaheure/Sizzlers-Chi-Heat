# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### More Chicagoans lacked heat in January than any month since 2019 amid historic cold
#
# 1. Go to the Chicago Data Portal: https://data.cityofchicago.org/
# 2. Find each dataset. Building violations, ward, and police.
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
build = pd.read_csv('https://data.cityofchicago.org/resource/22u3-xenr.csv?$limit=3000000')

# %%
# you can use any of these
ward = gpd.read_file('https://data.cityofchicago.org/api/geospatial/sp34-6z76?method=export&format=GeoJSON')
police = gpd.read_file('https://data.cityofchicago.org/api/geospatial/fthy-xz3r?method=export&format=GeoJSON')

# %%
# how a heat complaint is defined

# %%
build.head(3)
# Out:
#         id violation_last_modified_date           violation_date  \
# 0  7149072      2024-04-15T14:26:19.000  2024-04-15T00:00:00.000
# 1  7149214      2024-04-15T11:42:25.000  2024-04-15T00:00:00.000
# 2  7149177      2024-04-15T14:47:14.000  2024-04-15T00:00:00.000
#
#   violation_code violation_status violation_status_date  \
# 0         BR3055             OPEN                   NaN
# 1       CN077014             OPEN                   NaN
# 2         EV1110             OPEN                   NaN
#
#             violation_description   violation_location  \
# 0                         REPLACE                  NaN
# 1                    REPAIR FENCE  OTHER   :    :OTHER
# 2  MAINTAIN OR REPAIR ELECT ELEVA                  NaN
#
#                         violation_inspector_comments  \
# 0  BR3055: #10 FUL 23 HWB NB#:REPLACE CARBON MONO...
# 1  EAST ELEVATION / CHAINLINK FENCE / POSTS - BEN...
# 2                       CLOSE OPEN PERMIT #100093372
#
#                                  violation_ordinance  ...           address  \
# 0                                            Replace  ...  7342 S HOYNE AVE
# 1  Failed to maintain fence in good condition and...  ...     73 E 100TH ST
# 2  Failed to maintain electric elevator equipment...  ...  3550 S GILES AVE
#
#    street_number street_direction street_name street_type property_group ssa  \
# 0           7342                S       HOYNE         AVE         412791 NaN
# 1             73                E       100TH          ST         489776 NaN
# 2           3550                S       GILES         AVE         296866 NaN
#
#     latitude  longitude                                        location
# 0  41.759868 -87.675984  \n,  \n(41.75986812942321, -87.67598380492386)
# 1  41.712561 -87.620822  \n,  \n(41.71256122809906, -87.62082222334602)
# 2  41.829652 -87.619449  \n,  \n(41.82965177584204, -87.61944871099566)
#
# [3 rows x 26 columns]

# %%
build.tail(3)
# Out:
#               id violation_last_modified_date           violation_date  \
# 1906639  1498323      2008-05-16T09:51:15.000  2006-01-01T00:00:00.000
# 1906640  1345297      2007-07-31T15:01:51.000  2006-01-01T00:00:00.000
# 1906641  1504822      2006-07-24T13:37:32.000  2006-01-01T00:00:00.000
#
#         violation_code violation_status    violation_status_date  \
# 1906639       CN070034         COMPLIED  2008-04-10T00:00:00.000
# 1906640       CN104015             OPEN                      NaN
# 1906641       CN070014             OPEN                      NaN
#
#                  violation_description violation_location  \
# 1906639              REPLACE D&H PORCH                NaN
# 1906640  REPLCE WINDOW PANES, PLEXGLAS                NaN
# 1906641          REPAIR EXTERIOR STAIR                NaN
#
#                               violation_inspector_comments  \
# 1906639  3250 - 52 1ST AND 2ND ROTTED (LOOK OUTS) 6X6 B...
# 1906640                                  EAST WINDOW PANES
# 1906641  NO GUARD OR HANDRAIL AT SOUTH STAIRS GRADE TO ...
#
#                                        violation_ordinance  ...  \
# 1906639  Failed to rebuild or replace dilapidated and d...  ...
# 1906640  Replace broken, missing or defective window pa...  ...
# 1906641  Failed to maintain exterior stairways in safe ...  ...
#
#                       address  street_number street_direction street_name  \
# 1906639  2803 N SPAULDING AVE           2803                N   SPAULDING
# 1906640    5108 S CALUMET AVE           5108                S     CALUMET
# 1906641    7152 S EMERALD AVE           7152                S     EMERALD
#
#         street_type property_group   ssa   latitude  longitude  \
# 1906639         AVE           8578   NaN  41.932153 -87.709718
# 1906640         AVE         327758  52.0  41.801766 -87.617887
# 1906641         AVE          20462   NaN  41.763664 -87.643137
#
#                                                location
# 1906639  \n,  \n(41.93215331688343, -87.70971838467266)
# 1906640   \n,  \n(41.80176555860429, -87.6178867686376)
# 1906641  \n,  \n(41.76366389786062, -87.64313670468162)
#
# [3 rows x 26 columns]

# %%
build.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1906642 entries, 0 to 1906641
# Data columns (total 26 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   id                            int64
#  1   violation_last_modified_date  object
#  2   violation_date                object
#  3   violation_code                object
#  4   violation_status              object
#  5   violation_status_date         object
#  6   violation_description         object
#  7   violation_location            object
#  8   violation_inspector_comments  object
#  9   violation_ordinance           object
#  10  inspector_id                  object
#  11  inspection_number             int64
#  12  inspection_status             object
#  13  inspection_waived             object
#  14  inspection_category           object
#  15  department_bureau             object
#  16  address                       object
#  17  street_number                 int64
#  18  street_direction              object
#  19  street_name                   object
#  20  street_type                   object
#  21  property_group                int64
#  22  ssa                           float64
#  23  latitude                      float64
#  24  longitude                     float64
#  25  location                      object
# dtypes: float64(3), int64(4), object(19)
# memory usage: 378.2+ MB

# %%
build.shape
# Out:
# (1906642, 26)

# %%
build.columns
# Out:
# Index(['id', 'violation_last_modified_date', 'violation_date',
#        'violation_code', 'violation_status', 'violation_status_date',
#        'violation_description', 'violation_location',
#        'violation_inspector_comments', 'violation_ordinance', 'inspector_id',
#        'inspection_number', 'inspection_status', 'inspection_waived',
#        'inspection_category', 'department_bureau', 'address', 'street_number',
#        'street_direction', 'street_name', 'street_type', 'property_group',
#        'ssa', 'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
police.columns
# Out:
# Index(['dist_label', 'dist_num', 'geometry'], dtype='object')

# %%
ward.columns
# Out:
# Index(['shape_area', 'shape_leng', 'ward', 'geometry'], dtype='object')

# %%
police.columns
# Out:
# Index(['dist_label', 'dist_num', 'geometry'], dtype='object')

# %%
build_heat = build[build['violation_description'] == 'HEAT UNIT ADEQUATELY']

# %%
build_heat.head(3)
# Out:
#           id violation_last_modified_date           violation_date  \
# 30   7148900      2024-04-15T09:05:32.000  2024-04-15T00:00:00.000
# 519  7145591      2024-04-08T14:44:35.000  2024-04-08T00:00:00.000
# 566  7146237      2024-04-08T13:05:35.000  2024-04-08T00:00:00.000
#
#     violation_code violation_status violation_status_date  \
# 30        CN132016             OPEN                   NaN
# 519       CN132016             OPEN                   NaN
# 566       CN132016             OPEN                   NaN
#
#     violation_description   violation_location  \
# 30   HEAT UNIT ADEQUATELY       INTERIOR:002 :
# 519  HEAT UNIT ADEQUATELY       INTERIOR:002 :
# 566  HEAT UNIT ADEQUATELY  OTHER   :    :OTHER
#
#                           violation_inspector_comments  \
# 30   1263 S CENTRAL PARK APT 2 / ALL ROOMS 72F DEGR...
# 519  2207 S / APT.2 / ALL ROOMS - 64F DEGREES; AT (...
# 566  CB132016 - 2ND FLOOR BEDROOMS TEMP WAS 66F AT ...
#
#                                    violation_ordinance  ...  \
# 30   Heat dwelling unit adequately from September 1...  ...
# 519  Heat dwelling unit adequately from September 1...  ...
# 566  Heat dwelling unit adequately from September 1...  ...
#
#                      address  street_number street_direction   street_name  \
# 30   1263 S CENTRAL PARK AVE           1263                S  CENTRAL PARK
# 519      2207 S RIDGEWAY AVE           2207                S      RIDGEWAY
# 566       6753 S LOOMIS BLVD           6753                S        LOOMIS
#
#     street_type property_group ssa   latitude  longitude  \
# 30          AVE          15707 NaN  41.864450 -87.715218
# 519         AVE          26373 NaN  41.851364 -87.718497
# 566        BLVD         397833 NaN  41.770705 -87.658975
#
#                                             location
# 30   \n,  \n(41.864450173563014, -87.71521848941047)
# 519   \n,  \n(41.85136381385009, -87.71849743242603)
# 566   \n,  \n(41.77070465111202, -87.65897462365271)
#
# [3 rows x 26 columns]

# %%
build_heat['violation_date'] = pd.to_datetime(build_heat['violation_date'])
# Out:
# <ipython-input-45-5008936568e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   build_heat['violation_date'] = pd.to_datetime(build_heat['violation_date'])

# %%
build_heat['year'] = build_heat['violation_date'].dt.year
# Out:
# <ipython-input-46-5e4d1449b5ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   build_heat['year'] = build_heat['violation_date'].dt.year

# %%
build_heat['month'] = build_heat['violation_date'].dt.month
# Out:
# <ipython-input-49-e04d8deb9713>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   build_heat['month'] = build_heat['violation_date'].dt.month

# %%
build_heat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12669 entries, 30 to 1905305
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            12669 non-null  int64
#  1   violation_last_modified_date  12669 non-null  object
#  2   violation_date                12669 non-null  datetime64[ns]
#  3   violation_code                12669 non-null  object
#  4   violation_status              12669 non-null  object
#  5   violation_status_date         2223 non-null   datetime64[ns]
#  6   violation_description         12669 non-null  object
#  7   violation_location            7776 non-null   object
#  8   violation_inspector_comments  12572 non-null  object
#  9   violation_ordinance           12669 non-null  object
#  10  inspector_id                  12669 non-null  object
#  11  inspection_number             12669 non-null  int64
#  12  inspection_status             12666 non-null  object
#  13  inspection_waived             12669 non-null  object
#  14  inspection_category           12669 non-null  object
#  15  department_bureau             12669 non-null  object
#  16  address                       12669 non-null  object
#  17  street_number                 12669 non-null  int64
#  18  street_direction              12669 non-null  object
#  19  street_name                   12669 non-null  object
#  20  street_type                   12604 non-null  object
#  21  property_group                12669 non-null  int64
#  22  ssa                           2627 non-null   float64
#  23  latitude                      12665 non-null  float64
#  24  longitude                     12665 non-null  float64
#  25  location                      12665 non-null  object
#  26  month                         12669 non-null  int32
#  27  year                          12669 non-null  int32
# dtypes: datetime64[ns](2), float64(3), int32(2), int64(4), object(17)
# memory usage: 2.7+ MB

# %%
build_heat.head()
# Out:
#           id violation_last_modified_date violation_date violation_code  \
# 30   7148900      2024-04-15T09:05:32.000     2024-04-15       CN132016
# 519  7145591      2024-04-08T14:44:35.000     2024-04-08       CN132016
# 566  7146237      2024-04-08T13:05:35.000     2024-04-08       CN132016
# 862  7144562      2024-04-04T13:10:34.000     2024-04-04       CN132016
# 875  7144175      2024-04-04T13:01:43.000     2024-04-04       CN132016
#
#     violation_status violation_status_date violation_description  \
# 30              OPEN                   NaT  HEAT UNIT ADEQUATELY
# 519             OPEN                   NaT  HEAT UNIT ADEQUATELY
# 566             OPEN                   NaT  HEAT UNIT ADEQUATELY
# 862             OPEN                   NaT  HEAT UNIT ADEQUATELY
# 875             OPEN                   NaT  HEAT UNIT ADEQUATELY
#
#       violation_location                       violation_inspector_comments  \
# 30        INTERIOR:002 :  1263 S CENTRAL PARK APT 2 / ALL ROOMS 72F DEGR...
# 519       INTERIOR:002 :  2207 S / APT.2 / ALL ROOMS - 64F DEGREES; AT (...
# 566  OTHER   :    :OTHER  CB132016 - 2ND FLOOR BEDROOMS TEMP WAS 66F AT ...
# 862       INTERIOR:002 :  2ND FLOOR APT - ROOM TEMPERATURES WERE 62-64 D...
# 875  OTHER   :    :OTHER  UNIT 104 / ROOM TEMPERATURES : BEDROOM AT FRON...
#
#                                    violation_ordinance  ... street_direction  \
# 30   Heat dwelling unit adequately from September 1...  ...                S
# 519  Heat dwelling unit adequately from September 1...  ...                S
# 566  Heat dwelling unit adequately from September 1...  ...                S
# 862  Heat dwelling unit adequately from September 1...  ...                S
# 875  Heat dwelling unit adequately from September 1...  ...                S
#
#       street_name street_type property_group ssa   latitude  longitude  \
# 30   CENTRAL PARK         AVE          15707 NaN  41.864450 -87.715218
# 519      RIDGEWAY         AVE          26373 NaN  41.851364 -87.718497
# 566        LOOMIS        BLVD         397833 NaN  41.770705 -87.658975
# 862   ST LAWRENCE         AVE         393366 NaN  41.771441 -87.610718
# 875    BLACKSTONE         AVE          19107 NaN  41.790078 -87.590369
#
#                                             location month  year
# 30   \n,  \n(41.864450173563014, -87.71521848941047)     4  2024
# 519   \n,  \n(41.85136381385009, -87.71849743242603)     4  2024
# 566   \n,  \n(41.77070465111202, -87.65897462365271)     4  2024
# 862   \n,  \n(41.77144133889547, -87.61071830476385)     4  2024
# 875   \n,  \n(41.79007818420464, -87.59036862158871)     4  2024
#
# [5 rows x 28 columns]
