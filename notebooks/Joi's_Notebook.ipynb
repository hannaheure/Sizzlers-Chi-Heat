# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### More Chicagoans lacked heat in January than any month since 2019 amid historic cold
#
# 1. Go to the Chicago Data Portal: https://data.cityofchicago.org/
# 2. Find each dataset. Building violations, ward, and police.
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
build = pd.read_csv('https://data.cityofchicago.org/resource/22u3-xenr.csv?$limit=3000000')

# %%
# you can use any of these
ward = gpd.read_file('https://data.cityofchicago.org/api/geospatial/sp34-6z76?method=export&format=GeoJSON')
police = gpd.read_file('https://data.cityofchicago.org/api/geospatial/fthy-xz3r?method=export&format=GeoJSON')

# %%
#Testing that this import of the 'build' dataset works using .head()
build.sample(10)
# Out:
#               id violation_last_modified_date           violation_date  \
# 471165   5764161      2017-06-20T13:33:04.000  2017-06-20T00:00:00.000
# 758682   5072517      2020-04-20T08:08:25.000  2015-03-20T00:00:00.000
# 303893   6254935      2019-05-15T10:23:46.000  2019-01-07T00:00:00.000
# 1073010  4121349      2012-03-14T13:46:37.000  2012-03-14T00:00:00.000
# 461683   5781281      2017-07-24T11:11:31.000  2017-07-19T00:00:00.000
# 1320630  3401577      2010-02-11T14:25:22.000  2010-02-11T00:00:00.000
# 874350   4686390      2014-03-20T09:04:33.000  2014-03-20T00:00:00.000
# 1209131  3774408      2011-11-23T08:32:37.000  2011-02-22T00:00:00.000
# 762471   5678429      2017-11-27T09:28:09.000  2015-03-09T00:00:00.000
# 549522   5533437      2016-10-11T11:58:22.000  2016-10-11T00:00:00.000
#
#         violation_code violation_status    violation_status_date  \
# 471165        CN077024             OPEN                      NaN
# 758682        PL153017         COMPLIED  2020-04-20T00:00:00.000
# 303893          VT1010             OPEN                      NaN
# 1073010       CN015062             OPEN                      NaN
# 461683          EV1110             OPEN                      NaN
# 1320630         NC2010             OPEN                      NaN
# 874350        CN015012             OPEN                      NaN
# 1209131       CN105085         COMPLIED  2011-11-22T00:00:00.000
# 762471        CN197087             OPEN                      NaN
# 549522        CN070034             OPEN                      NaN
#
#                   violation_description  \
# 471165    NO BARBED WIRE ON FENCE < 8FT
# 758682         REPLACE DEFECTIVE FAUCET
# 303893   ARRANGE COMPLETED PERMIT INSP.
# 1073010        OBSTRUCTIONS IN EXIT WAY
# 461683   MAINTAIN OR REPAIR ELECT ELEVA
# 1320630        PLANS & PERMITS REQUIRED
# 874350          NO KEY TO USE EXIT DOOR
# 1209131   PROVIDE DEADLOCK FOR ENTRANCE
# 762471       CARB MONOX DETECT IN RESID
# 549522                REPLACE D&H PORCH
#
#                             violation_location  \
# 471165                  OTHER   :    :EXTERIOR
# 758682                                     NaN
# 303893   5757-5759 N BROADWAY/1133-39 W ADMORE
# 1073010                         INTERIOR:-1  :
# 461683                                     NaN
# 1320630                         OTHER   :    :
# 874350                          OTHER   :    :
# 1209131         EXTERIOR:S   :#2838-42 BL01037
# 762471                        OTHER   :    :::
# 549522                          OTHER   :    :
#
#                               violation_inspector_comments  \
# 471165   REAR ELEVATION / METAL FENCE - RAZOR WIRE INST...
# 758682   KITCHEN SINK FAUCET IS LOOSE AND DRIPS 1ST FLOOR.
# 303893   18-28/-106.1 INSPECTION REQUIRED ARRANGE FOR C...
# 1073010  BASEMENT - GARAGE - RECEIVING ROOM - DESKS, SH...
# 461683                         IDENTIFY MACHINE ROOM DOOR.
# 1320630                  NO PERMIT OR PLANS TO BREACH WALL
# 874350                  FRONT YARD GATE - DOUBLE KEY LOCK.
# 1209131         FRONT ENTRY DOORS - DEADBOLT LOCKS MISSING
# 762471   7205 S. / APT. 3A AND 7207 S. / APT. 2A - CARB...
# 549522   1-STORY REAR PORCH IS IN DANGEROUS AND HAZARDO...
#
#                                        violation_ordinance  ... street_number  \
# 471165   Failed to remove barbed wire from fence less t...  ...          1725
# 758682   Repair or replace defective faucet. (18-29-102...  ...           605
# 303893   Arrange mechanical ventilation or warm air hea...  ...          5757
# 1073010  Failed to remove obstruction from exitway that...  ...          1401
# 461683   Failed to maintain electric elevator equipment...  ...           329
# 1320630  Failed to submit drawings or plans for approva...  ...          1500
# 874350   Failed to equip exit door with door lock hardw...  ...          2923
# 1209131  Failed to provide and install building entranc...  ...          7957
# 762471   Install carbon monoxide detector within 40 fee...  ...          7201
# 549522   Failed to rebuild or replace dilapidated and d...  ...          1260
#
#          street_direction street_name street_type property_group   ssa  \
# 471165                  W       NORTH         AVE           4755  33.0
# 758682                  N     LARAMIE         AVE          42307   NaN
# 303893                  N    BROADWAY         NaN          12378  26.0
# 1073010                 E        55TH          ST          19138   NaN
# 461683                  W        18TH          ST          16058   NaN
# 1320630                 E        63RD          ST         361258   NaN
# 874350                  N        TROY          ST         116754   NaN
# 1209131                 S    MUSKEGON         AVE         665455  49.0
# 762471                  S   VINCENNES         AVE          20452   NaN
# 549522                  W        74TH          PL         411627   NaN
#
#           latitude  longitude  \
# 471165   41.910473 -87.671136
# 758682   41.891511 -87.755327
# 303893   41.987161 -87.660031
# 1073010  41.795400 -87.591626
# 461683   41.857617 -87.636071
# 1320630  41.780691 -87.588915
# 874350   41.934582 -87.706122
# 1209131  41.750211 -87.555144
# 762471   41.763499 -87.628692
# 549522   41.758761 -87.656301
#
#                                                 location   heat
# 471165   \n,  \n(41.910472740615525, -87.67113557164183)  False
# 758682    \n,  \n(41.89151137458952, -87.75532712627879)  False
# 303893    \n,  \n(41.98716055062304, -87.66003099584046)  False
# 1073010   \n,  \n(41.79539991193184, -87.59162590876223)  False
# 461683    \n,  \n(41.85761688731556, -87.63607109247158)  False
# 1320630  \n,  \n(41.780690624537755, -87.58891524958786)  False
# 874350    \n,  \n(41.93458161459121, -87.70612197429169)  False
# 1209131   \n,  \n(41.75021062094856, -87.55514363984939)  False
# 762471    \n,  \n(41.76349946003194, -87.62869204438374)  False
# 549522    \n,  \n(41.75876144484724, -87.65630081225434)  False
#
# [10 rows x 27 columns]

# %%
build['heat_code'] = build['violation_code'].str.contains

# %%
build.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1906071 entries, 0 to 1906070
# Data columns (total 27 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   id                            int64
#  1   violation_last_modified_date  object
#  2   violation_date                object
#  3   violation_code                object
#  4   violation_status              object
#  5   violation_status_date         object
#  6   violation_description         object
#  7   violation_location            object
#  8   violation_inspector_comments  object
#  9   violation_ordinance           object
#  10  inspector_id                  object
#  11  inspection_number             int64
#  12  inspection_status             object
#  13  inspection_waived             object
#  14  inspection_category           object
#  15  department_bureau             object
#  16  address                       object
#  17  street_number                 int64
#  18  street_direction              object
#  19  street_name                   object
#  20  street_type                   object
#  21  property_group                int64
#  22  ssa                           float64
#  23  latitude                      float64
#  24  longitude                     float64
#  25  location                      object
#  26  heat                          bool
# dtypes: bool(1), float64(3), int64(4), object(19)
# memory usage: 379.9+ MB

# %%
build['heat'] = build['violation_description'].str.contains('HEAT') == True

# %%
build.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1906071 entries, 0 to 1906070
# Data columns (total 27 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   id                            int64
#  1   violation_last_modified_date  object
#  2   violation_date                object
#  3   violation_code                object
#  4   violation_status              object
#  5   violation_status_date         object
#  6   violation_description         object
#  7   violation_location            object
#  8   violation_inspector_comments  object
#  9   violation_ordinance           object
#  10  inspector_id                  object
#  11  inspection_number             int64
#  12  inspection_status             object
#  13  inspection_waived             object
#  14  inspection_category           object
#  15  department_bureau             object
#  16  address                       object
#  17  street_number                 int64
#  18  street_direction              object
#  19  street_name                   object
#  20  street_type                   object
#  21  property_group                int64
#  22  ssa                           float64
#  23  latitude                      float64
#  24  longitude                     float64
#  25  location                      object
#  26  heat                          bool
# dtypes: bool(1), float64(3), int64(4), object(19)
# memory usage: 379.9+ MB

# %%
#converting column to a string value by using .astype
build['heat'] = build['heat'].astype(str)

# %%
build.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1906071 entries, 0 to 1906070
# Data columns (total 27 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   id                            int64
#  1   violation_last_modified_date  object
#  2   violation_date                object
#  3   violation_code                object
#  4   violation_status              object
#  5   violation_status_date         object
#  6   violation_description         object
#  7   violation_location            object
#  8   violation_inspector_comments  object
#  9   violation_ordinance           object
#  10  inspector_id                  object
#  11  inspection_number             int64
#  12  inspection_status             object
#  13  inspection_waived             object
#  14  inspection_category           object
#  15  department_bureau             object
#  16  address                       object
#  17  street_number                 int64
#  18  street_direction              object
#  19  street_name                   object
#  20  street_type                   object
#  21  property_group                int64
#  22  ssa                           float64
#  23  latitude                      float64
#  24  longitude                     float64
#  25  location                      object
#  26  heat                          object
# dtypes: float64(3), int64(4), object(20)
# memory usage: 392.6+ MB

# %%
build['violation_description'].value_counts()
# Out:
# violation_description
# ARRANGE PREMISE INSPECTION        101402
# MAINTAIN OR REPAIR ELECT ELEVA     64822
# REPAIR EXTERIOR WALL               61079
# POST OWNER/MANAGERS NAME/#         57784
# REPAIR PORCH SYSTEM                49011
#                                    ...
# LANDSCAPING REVIEW DID NOT PA          1
# COMPL LOAD CALC IN ACCORDANCE          1
# PROVIDE VENTPIPE ON OIL TANKS          1
# COMPLETE HEATING SECTION ON PA         1
# REP/REPL LOBBY FIRE KEY SW F           1
# Name: count, Length: 1389, dtype: int64

# %%
build['heat'].unique()
# Out:
# array(['False', 'True'], dtype=object)
